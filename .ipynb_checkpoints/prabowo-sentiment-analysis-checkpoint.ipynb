# %%
# load pandas
import pandas as pd


# load data
raw_data = pd.read_csv('tweets-data/prabowo_12-04-2024_20-03-17.csv')

# %%
# select full_text
tweet_text = raw_data[['full_text']]


# Checking the data
tweet_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   full_text  118 non-null    object
# dtypes: object(1)
# memory usage: 1.1+ KB

# %%
# Drop duplicated full text
tweet_text = tweet_text.drop_duplicates()


tweet_text.duplicated().sum()


# Check the shape
tweet_text.shape
# Out:
# (118, 1)

# %%
import re

# Creating function for cleaning full text
def clean_tweet_text(text):
    text = re.sub(r'@[A-Za-z0-9_]+', ' ', text)
    text = re.sub(r'#\w+', ' ', text)
    text = re.sub(r'RT[\s]+', ' ', text)
    text = re.sub(r'https?://\S+', ' ', text)
    text = re.sub(r'[^A-Za-z0-9]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()

    return text

tweet_text['full_text'] = tweet_text['full_text'].apply(clean_tweet_text)

# Check the data
tweet_text.head()

# Case folding full_text
tweet_text['full_text'] = tweet_text['full_text'].str.lower()


for text in tweet_text['full_text']:
    print(text)
# Out:
# pilpres telah usai ramadhanpun berlalu hari ini harus lebih baik dari kemarin dan masa depan harus lebih baik dari hari ini berbagai program 02 disusun menuju indonesia emas 2024 menjadi negara raksasa ke 4 di dunia tak ada yg instan tahapan dimulai
# segoblok gobloknya presiden hari ini dia bisa memecat panglima kapan saja dia mau yusril izha mahendra gue makin yakin orang2 yang dibelakang prabowo sebenarnya ga sepenuhnya sayang jokowi mereka2 hanya menggunakan jokowi sebagai kendaraan dan alat meraih kekuasaan
# perbedaan open house prabowo dan anies baswedan
# pdi p masih belum menghendaki pertemuan prabowo dengan megawati
# prabowo menyambangi rumah megawati ya sudah gua ikhlas prabowo jadi presiden asal gibran di diskualifikasi untuk meredam konflik gugatan pilpres agar kostitusi tetap terjaga apakah kalian setuju tinggalkan jejak kalian
# piye sampai kpan ucapan prilaku hati nurani bisa slaras apakah materi harta tahta amp jabatan mampu mengangkat derajat sukma stelah raga di kubur sesungguhnya kehidupan alam fana tingkat yg paling rendah dari kehidupan lain dialam smesta
# aku pemilih prabowo gibran itu dari hati nuraniku sendiri bukan karena bansos camkan itu bambang goblok tolol aku memang orang miskin tapi kalau kamu hina kami miskin kami tidak terima satu kata buat kamu bambang bajingan kami tidak pilih anis ganjar sombong
# refly harun suara prabowo sebelum gibran dicalonkan elektabilitasnya hanya 24 ketika gibran dicalonkan 25 oktober 2023 bagaimana dalam waktu 4 bulan bisa mendapatkan kenaikan 30 lebih berapa kali prabowo gibran berkampanye jarang datang tapi ada faktor lain yg mendukung
# kepada bapak amp bu media2 israel cukup sering membuat berita tentang normalisasi hubungan antara indonesia israel indonesia diberitakan bersedia mengakui israel agar bisa bergabung dengan oecd
# prabowo and the red carpet
# gibran 36 thn saat mendaftar sementara pkpu nya masih berlaku usia 40 thn 16 oktober putusan mk 25 oktober prabowo gibran mendaftar 3 november penyesuaian pkpu yg baru hasil putusan mk parah nya lagi 13 november penetapan capres cawapres msh pakai pkpu lama
# hei pendukung 02 saya kasih tahu ya di forum debat untuk cegah korupsi prabowo bilang akan naikkan gaji pejabat dan gibran bilang akan naikkan pajak itu artinya yang kaya makin kaya yang miskin makin miskin
# puan nanti jadi ketum akan narik kembali mas gibran agar pdip kembali berjaya anggaplah mas gibran magang 5 atau 10 tahun sebagai wapres utk persiapan pengganti pak prabowo
# perbedaan nyata antara anies baswesan amp prabowo dapat dilihat saat open house
# sebagai penutup twitt malam ini ada yg tidak menyukai persahabatan mereka dan menfitnah bahwa prabowo perlahan meninggalkan jokowi maaf kalian tidak mengenal beliau selama kebencian itu tetap di tanam
# warganet ni ungkap perbedaan open house anies dan prabowo
# keberatan tim hukum prabowo gibran ditolak hakim mk karena video yang akan ditayangkan sudah menjadi barbuk di mk jadi harus di putar oleh pemohon kesan nya tim hukum 02 gelisah dan cemas semoga pqra hakim tidak takut le penguasa saat ini
# siap siap buzzer sama pendukungnya prabowo merangkap jadi hasbara we are in for some ugly shit
# denny indrayana soal prabowo dilantik tanpa gibran jika terbukti langgar konstitusi mpr bisa lantik cawapres lain
# shombhong
# akibat deklarasi kemenangan 02 dan bertemu xi karpet merah terus berlanjut sementara pengangguran negri ini semakin bertambah ada apa dengan pemikiran pejabat bangsa ini
# anwar the chinese puppets vs prabowo zionism
# food estate legacy nya
# hakim mk saldi isra pegang peta kekalahan prabowo hakim mk saldi isra tanya ke 4 menteri kenapa presiden jokowi lebih sering ke jawa tengah
# prof ridwan guru besar hukum administrasi uii yogyakarta saksi ahli di mk pencalonan gibran r sebagai cawapres prabowo dinilai tidak sah kpu tdk punya kekuataan hukum diskresi utk menerima pencalonan gibran link
# pengubahan istilah kkb ke opm oleh tni menunjukkan ada perbedaan antara tni dengan polri dalam penanganan papua kesabaran tni makin tipis terhadap metode operasi penegakan hukum yg dipimpin polri sebagai sipil tni akan dapat lampu hijau ambil alih begitu prabowo naik
# ahli prabowo sebut posisi presiden bisa kosong jika mk kabulkan gugatan anies dan ganjar
# beathor usulkan prabowo dilantik jadi presiden 2024 2029 tanpa gibran yang didiskualifikasi mk
# astaga warganet ini ungkap perbedaan anies dan prabowo ketika open house anies bareng rakyat sementara prabowo bareng artis
# bapak calon wakil presiden nggak faham permasalahan bahasanya erooor ngebleng piye katanya bapak dan bapak calon presiden nasionalis nkri lah kok tka china terus berdatangan hingga saat ini 1 bersambung
# tas bansosnya bergambar prabowo gibran masa yang didiskualifikasi cuma gibran diskualifikasi prabowo gibran dong biar mantap
# prabowo saja mengatakan kalau pemilu curang lah kok pendukungnya yg ngeyel kl pemilu itu jurdil jangan pendukungnya orang gila semua ya
# tim amin sebut pertemuan anies prabowo perlu kalkulasi politik yang matang
# pdip makin mendekat ke prabowo signal gibran akan diskualifikasi
# penggunaan ai oleh tim prabowo ternyata melanggar peraturan lembaga ai yang melarang penggunaan ai untuk kampanye politik berikut artikel yang menjelaskan hal ini
# pengamat berkirim surat ke kpu agar terima pendaftaran prabowo gibran jokowi sudah melanggar uu dan etika
# propaganda terselubung china xi jinping undang prabowo china mulai panik
# prabowo pleciden oke gass oke gass oke gass 3x
# prabowo gibran harus kalah jokowi harus diberi pelajaran dia melakukan praktik nepotisme amp cawe2 terang terangan harus dibuat aturan juga bahwa di akhir masa jabatan harus dipincangkan seperti di amerika eep
# rocky gerung sebaiknya dilakukan pemungutan suara ulang untuk membuktikan bahwa variabel bansos jokowi yang menentukan kemenangan suara prabowo gibran
# ide yg briliant buat pak prabowo sekalian khianatin sponsor utama pak
# timnas amin kemenangan prabowo gibran di 19 provinsi harus ditolak karena terindikasi kecurangan 36 19 provinsi sisa 17 saja duaaaaaaarrrr
# hasto menyerang jokowi terus menerus sementara puan mendekati prabowo dan terkesan menjadikan hak angket sbg tukar tambah lagi main apa kalian skr
# pemilu ulang tanpa gibran win win solution untuk prabowo anies dan ganjar
# it is a great honor for me to receive a congratulatory call from the president of the republic of t rkiye h e recep tayyip erdo an on the result of the indonesian presidential election t rkiye is a great friend to indonesia and we believe that this friendship
# musuh kita dinasti politik wanita ini sebut musuhnya bukan prabowo tapi dinasti politik
# prabowo magically summoning two thousand unnamed indonesian to be racist online and distract people from his normalizing deal with israel
# ahli prabowo gibran sebut bansos tak pengaruhi pemilih todung mencederai akal sehat
# naluri kebapakan pak prabowo muncul saat mengetahui gibran belum bersilaturahmi dgn kedua orangtuanya
# program makan siang gratis prabowo gibran tidak masuk akal 1 itu pembodohan publik 2 tidak ada detail apbn untuk makan siang gratis dananya dari mana berapa besarnya dan berapa pajak yang akan dibebankan itu tidak masuk akal bima yudhistira indef
# 04 01 2024 south china morning post amid growing tensions in the south china sea indonesia s newly elected president prabowo chose the communist china for his first trip and pledged to retain close relations with the ccp
# nih buktinya keberlanjutan
# bamsoet dukung prabowo rangkul semua parpol kita tidak butuh oposisi
# belum pernah ada ikatan emosional yg sekuat amp sedekat prabowo amp gibran di antara semua capres amp cawapres bahkan di antara semua presiden amp wapresnya terlihat sekali mereka berdua saling menyayangi prabowo begitu menghargai gibran sebaliknya gibran sangat menghormati bapak
# guru besar ipdn sebut dukungan presiden jokowi dongkrak suara prabowo gibran para pj dengan segala cara dilakukan untuk memenangkan 02 agar karir birokrasinya aman
# pengamat prediksi kecil kemungkinan mk diskualifikasi prabowo gibran
# kebohongan membenci tiongkok dan israel ternyata menjalin hubungan mersra dengan keduanya betulkan alih ingin majukan indonesia faktanya tka china terus berdatangan menguras seluruh sumber alam di berbagai daerah terlalu
# rakyat hanya ingin prabowo gibran didiskualifikasi cc kalau cukup 1 putaran 02 diskualifikasi 01 naik gampang
# selamat lebaran pak we love you
# saat di china dengarkan menit ke 1 28 once again i would emphasize that i would like to continue the policy of the president pemindahan penduduk china untuk dilanjutkan ngeriii prabowo seperti sedang menghadap bos besar
# diyakini oleh para orang tua bahwa benyamin thomas sigar paman pak prabowo adalah salah satu penangkap pangeran diponegoro thomas sigar bergabung dengan pasukan belanda pada perang jawa 1925 1930 antek penjajah
# rakyat ditakut takuti jika prabowo gibran didiskualifikasi akan terjadi chaos
# rakyat ditakut takuti jika prabowo gibran didiskualifikasi akan terjadi chaos
# heartbreaking news from west papua nepina aged 6 and fernando 12 victims of indonesian military violence in intan jaya perpetrators identified as tni kostrad 509 associated with prabowo
# elektabilitas prabowo sebelum ada gibran menurut refly harun 24 sekarang prabowo sangat diuntungkan oleh iklan gratis dari pengumuman pemenang kpu so diskualifikasi 02
# sometimes i m grateful that prabowo is the president just for one fact that the rest of his competition can spend time with their families because we all know prabowo doesn t have one to spend it
# rakyat hanya ingin prabowo gibran didiskualifikasi
# jenderal purnawirawan tni polri yang mendukung mk diskualifikasi prabowo gibran
# president spoke by phone with indonesian president elect prabowo subianto the call addressed the t rkiye indonesia relations and global developments congratulating indonesian president elect subianto on his election victory president erdo an expressed his
# selisih suara besar pan yakin prabowo gibran bakal memenangkan sengketa pilpres 2024 di mk
# rupanya veronica koman beny wenda dan jefry wenda akan pesta pora 30 hari berturut turut atas gugurnya danramil 1703 04 aradide kabupaten paniai letda inf oktovianus sogalrey
# lmao jadi selama ini bikin si gemoy pake midjourney dan specifically di tos nya ga boleh tapi ga kaget sih orang tim kampanye prabowo gibran sama midjourney sama sama ga punya dan ga peduli etika
# sepertinya banyak hal yg membuat saya mengatakan tidak untuk prabowo saya tetap anies
# indonesia president now mr prabowo as the commander in the military operations 1996 in west papua killing civilians indigenous peoples of west papua
# indonesian president elect prabowo is traveling the alert man in black is his personal guard major teddy
# 2024 keluarga inul vizta sesuai dugaan sebelumnya warna biru prabowo menjadi salah satu tren yang nggak terhindarkan di tahun ini mami inul dan mas adam suseno menggunakan gamis koko tabrak tabrak masuk sebagai outfit raya 2024
# bismillah suara penolakan dari papua ini langsung dari kepala suku papua mereka tidak melupakan tragedi yg terjadi di papua dulu mereka tdk melupakan tangan yg kotor dgn darah warga timor timur amp warga papua mereka tdk lupa
# emang bansos amplop amp pengerahan aparatur negara untuk gibran saja mendukung memilih dan memenangkan prabowo gibran rocky gerung mk masih bisa batalkan hasil kemenangan gibran tapi tidak prabowo
# tahun 2024 karir politik anis berahir
# manado torang gass demokrat bersama prabowo gibra vcs pdemokrat agusyudhoyono demokrat harapan rakyat
# di geneva vila vila mewah milih hashim djojohadikusumo prabowo s brother amp istrinya dijual oleh otoritas pajak setempat karena nunggak pajak bertahun tahun kalian kesulitan punya rumah di negeri sendiri sementara keluarga politisi yg kalian bela punya aset di luar negeri
# pan ini ngingetin gue ama lahan prabowo dituduh punya 300 hektar malah flexing 500 hektar
# menutup masa kampanye hadir all out di gbk untuk merapatkan barisan menangkan prabowo gibran oyh agusyudhoyono pdemokrat demokrat harapan rakyat
# ketua tpn ganjar mahfud minta bertemu prabowo
# omgg its so prabowo gibran 02 coded oke gas oke gas
# jangan tertipu sikap hakim mk said didu 2019 prabowo korban php
# jika pribumi kalah pemilu akan sangat mengerikan
# kata bobon peliharaaan prabowo lokasinya ditentuin mereka maybe biar gak ketahuan bobroknya
# setuju sama pak idul fitri momen merekatkan kembali persatuan bangsa saatnya dan kembali bersatu definisi pemimpin yang tepat ya gini nih
# gonna blame this to 02 supporters prabowo gibran jokowi scooter bang pd and ghoulpinks alias fuck yall
#
# shame
# prabowo couldn t agree more
# ksh analogi sederhana aja tanpa bantuan istana bs menang 2x gagal aplg yg ke 3 ini barisan kritis dan cerdasnya ke 01 kalau bs menang gk perlu susah payah 2019 jual wasiat dan timbul tenggelam dia menikmati permainan yg 2019 dipakai nyunsepin dia
# viral pendukung anies sebut andai bukan bulan puasa semua pendukung jokowi dan prabowo akan disembelih
# tenang ada yang jauh lebih sinting lagi dari pada cerita bl jokowi prabowo yaitu cerita bl prabowo anies
# jalan tengah prabowo dilantik tanpa gibran
# their new president prabowo is pro zionist so this was expected and not so surprising
# prabowo dapat banyak ucapan selamat zulkifli hasan dunia saja sudah mengakui
# pm anwar terima kunjungan hormat prabowo
# org ini jangan lagi menjadi cc
# milih kena prank viral gajih karyawan di potong pajak 1 juta rupiah semua apa yg bisa dipajakin dibuat aturan pajak demi mulangin uang bansos dan bunga utang weleh weleh
# what for why not go straight to gaza sir
# honoured amp delighted to have had the occasion to convey to president elect the heartfelt congratulations of president on his election as well as best wishes for
# jokowi berpeluang jadi penasihat khusus prabowo gibran
# njir gue stop aliran dana keluarga gue yg memuja prabowo dan jokowi biar mereka itu ngerasain dicekek oleh rezim durjana ini slma ini gue yg kecekek sendirian mereka di medsos sok kaya sok kaya mereka itu ada gue yg kerja mati2an jungkir balik sakit ttp kerja gua ksh peljran
# how lucky i m gemoy will never die prabowo presiden 2024
# hahaha hiburan sore utk haha hihi imam mahdi kalah sama prabowo gibran apalagi dajjal
# dear pak by taking neom concept beyond our funding talk could be held between malaysia amp brunei for point of strategic railway station amp sorrounding development i believe speed train initated by hrh could benefit whole borneo cc
# m qodari menjadi saksi ahli di sidang mk terkait sengketa pilpres 2024
# pengkhianatan partai politik dan kejahatan di mk saling melengkapi untuk tujuan menipu rakyat dari mega jokowi hingga prabowo hanya bersandiwa demi kepentingan pribadi dan kelompoknya saatnya satukan potensi membentuk partai baru sebagai wadah perjuangan kaum progresif
# turkish president recep tayyip erdogan congratulates indonesian president elect prabowo subianto on his victory discussing bilateral relations and global developments in phone call
# as michael buehler reported last month the family has fought to avoid the tax payment since the mid 2000s
# respon menohok babe haikal mau bilang curang ok curangnya berapa 1000 tps ambil semuanya utk amin 2000 tps ambil semua utk ganjar tidak akan mengurangi persentase pak prabowo kalah ya kalah aja
# sekarang si otto dkk beranikah menghadirkan jokowi dan prabowo
# bahlil lahadalia dan maruarar sirait ungkap soal peluang jokowi jadi penasihat khusus prabowo
# bamsoet sebut keluarga besar anak kolong berharap kepada prabowo
# pkb belum punya pengalaman di luar pemerintahan jadi kita lihat ucap waketum jazilul fawaid

# %%
# text normalize

norm = {' shombhong ':' sombong ', ' orang2 ':' orang-orang ', ' ok ':' oke ', ' bl ':'', ' amp ':'',
        ' tdk ':' tidak ', ' ga ':' tidak ', ' mslh ':' masalah ', ' yg ':' yang ', ' 3x ':'', ' cawe2 ':' cawe-cawe ',
        ' erooor ':' galat ', ' ngeblang ':' kosong ', ' piye ':' bagaimana ', ' gimana ':' bagaimana ', ' r ':'',
        ' ni ': ' ini '}

def normalize(text):
    for i in norm:
        text = text.replace(i, norm[i])

    return text

tweet_text['text_norm'] = tweet_text['full_text'].apply(normalize)

# Check the data
tweet_text.head()
# Out:
#                                            full_text  \
# 0  pilpres telah usai ramadhanpun berlalu hari in...
# 1  segoblok gobloknya presiden hari ini dia bisa ...
# 2    perbedaan open house prabowo dan anies baswedan
# 3  pdi p masih belum menghendaki pertemuan prabow...
# 4  prabowo menyambangi rumah megawati ya sudah gu...
#
#                                            text_norm
# 0  pilpres telah usai ramadhanpun berlalu hari in...
# 1  segoblok gobloknya presiden hari ini dia bisa ...
# 2    perbedaan open house prabowo dan anies baswedan
# 3  pdi p masih belum menghendaki pertemuan prabow...
# 4  prabowo menyambangi rumah megawati ya sudah gu...

# %%
# eliminating stopword
# install nltk
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\septi\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\septi\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\septi\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\septi\anaconda3\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\septi\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\septi\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
# Import nltk
import nltk


# Download stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\septi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
# import stopwords indonesia
from nltk.corpus import stopwords

stop = stopwords.words('indonesian')

# Implementing stopwords elimination
tweet_text['text_sw'] = tweet_text['text_norm'].apply(lambda x:' '.join([word for word in x.split() if word not in (stop)]))


# Check the data
tweet_text.head()
# Out:
#                                            full_text  \
# 0  pilpres telah usai ramadhanpun berlalu hari in...
# 1  segoblok gobloknya presiden hari ini dia bisa ...
# 2    perbedaan open house prabowo dan anies baswedan
# 3  pdi p masih belum menghendaki pertemuan prabow...
# 4  prabowo menyambangi rumah megawati ya sudah gu...
#
#                                            text_norm  \
# 0  pilpres telah usai ramadhanpun berlalu hari in...
# 1  segoblok gobloknya presiden hari ini dia bisa ...
# 2    perbedaan open house prabowo dan anies baswedan
# 3  pdi p masih belum menghendaki pertemuan prabow...
# 4  prabowo menyambangi rumah megawati ya sudah gu...
#
#                                              text_sw
# 0  pilpres ramadhanpun kemarin program 02 disusun...
# 1  segoblok gobloknya presiden memecat panglima y...
# 2        perbedaan open house prabowo anies baswedan
# 3                   pdi p pertemuan prabowo megawati
# 4  prabowo menyambangi rumah megawati ya gua ikhl...

# %%
# Tokenize
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize


tweet_text['token'] = tweet_text['text_sw'].apply(lambda x: word_tokenize(x))

tweet_text.head(10)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\septi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                            full_text  \
# 0  pilpres telah usai ramadhanpun berlalu hari in...
# 1  segoblok gobloknya presiden hari ini dia bisa ...
# 2    perbedaan open house prabowo dan anies baswedan
# 3  pdi p masih belum menghendaki pertemuan prabow...
# 4  prabowo menyambangi rumah megawati ya sudah gu...
# 5  piye sampai kpan ucapan prilaku hati nurani bi...
# 6  aku pemilih prabowo gibran itu dari hati nuran...
# 7  refly harun suara prabowo sebelum gibran dical...
# 8  kepada bapak amp bu media2 israel cukup sering...
# 9                         prabowo and the red carpet
#
#                                            text_norm  \
# 0  pilpres telah usai ramadhanpun berlalu hari in...
# 1  segoblok gobloknya presiden hari ini dia bisa ...
# 2    perbedaan open house prabowo dan anies baswedan
# 3  pdi p masih belum menghendaki pertemuan prabow...
# 4  prabowo menyambangi rumah megawati ya sudah gu...
# 5  piye sampai kpan ucapan prilaku hati nurani bi...
# 6  aku pemilih prabowo gibran itu dari hati nuran...
# 7  refly harun suara prabowo sebelum gibran dical...
# 8  kepada bapakbu media2 israel cukup sering memb...
# 9                         prabowo and the red carpet
#
#                                              text_sw  \
# 0  pilpres ramadhanpun kemarin program 02 disusun...
# 1  segoblok gobloknya presiden memecat panglima y...
# 2        perbedaan open house prabowo anies baswedan
# 3                   pdi p pertemuan prabowo megawati
# 4  prabowo menyambangi rumah megawati ya gua ikhl...
# 5  piye kpan ucapan prilaku hati nurani slaras ma...
# 6  pemilih prabowo gibran hati nuraniku bansos ca...
# 7  refly harun suara prabowo gibran dicalonkan el...
# 8  bapakbu media2 israel berita normalisasi hubun...
# 9                         prabowo and the red carpet
#
#                                                token
# 0  [pilpres, ramadhanpun, kemarin, program, 02, d...
# 1  [segoblok, gobloknya, presiden, memecat, pangl...
# 2  [perbedaan, open, house, prabowo, anies, baswe...
# 3             [pdi, p, pertemuan, prabowo, megawati]
# 4  [prabowo, menyambangi, rumah, megawati, ya, gu...
# 5  [piye, kpan, ucapan, prilaku, hati, nurani, sl...
# 6  [pemilih, prabowo, gibran, hati, nuraniku, ban...
# 7  [refly, harun, suara, prabowo, gibran, dicalon...
# 8  [bapakbu, media2, israel, berita, normalisasi,...
# 9                   [prabowo, and, the, red, carpet]

# %%
# Install Sastrawi
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ---------------------------------------- 0.0/209.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/209.7 kB ? eta -:--:--
#    - -------------------------------------- 10.2/209.7 kB ? eta -:--:--
#    ------- ------------------------------- 41.0/209.7 kB 487.6 kB/s eta 0:00:01
#    ---------------------------------------- 209.7/209.7 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
# Stemming
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()


# Create function for stemming
def stemmed_wrapper(text):
    return stemmer.stem(text)

text_dict = {}
count = 0

for row in tweet_text['token']:
    for text in row:
        if text not in text_dict:
            text_dict[text] = ' '

print(len(text_dict))

for word in text_dict:
    text_dict[word] = stemmed_wrapper(word)
    count+=1

# Adding stemmed text into the dataframe
def get_stemmed_text(text):
    return [text_dict[word] for word in text]


tweet_text['text_stem'] = tweet_text['token'].apply(lambda x: ' '.join(get_stemmed_text(x)))

tweet_text.head()
# Out:
# 1018
#                                            full_text  \
# 0  pilpres telah usai ramadhanpun berlalu hari in...
# 1  segoblok gobloknya presiden hari ini dia bisa ...
# 2    perbedaan open house prabowo dan anies baswedan
# 3  pdi p masih belum menghendaki pertemuan prabow...
# 4  prabowo menyambangi rumah megawati ya sudah gu...
#
#                                            text_norm  \
# 0  pilpres telah usai ramadhanpun berlalu hari in...
# 1  segoblok gobloknya presiden hari ini dia bisa ...
# 2    perbedaan open house prabowo dan anies baswedan
# 3  pdi p masih belum menghendaki pertemuan prabow...
# 4  prabowo menyambangi rumah megawati ya sudah gu...
#
#                                              text_sw  \
# 0  pilpres ramadhanpun kemarin program 02 disusun...
# 1  segoblok gobloknya presiden memecat panglima y...
# 2        perbedaan open house prabowo anies baswedan
# 3                   pdi p pertemuan prabowo megawati
# 4  prabowo menyambangi rumah megawati ya gua ikhl...
#
#                                                token  \
# 0  [pilpres, ramadhanpun, kemarin, program, 02, d...
# 1  [segoblok, gobloknya, presiden, memecat, pangl...
# 2  [perbedaan, open, house, prabowo, anies, baswe...
# 3             [pdi, p, pertemuan, prabowo, megawati]
# 4  [prabowo, menyambangi, rumah, megawati, ya, gu...
#
#                                            text_stem
# 0  pilpres ramadhanpun kemarin program 02 susun i...
# 1  goblok goblok presiden pecat panglima yusril i...
# 2             beda open house prabowo anies baswedan
# 3                        pdi p temu prabowo megawati
# 4  prabowo sambang rumah megawati ya gua ikhlas p...

# %%
# preparing for labeling
data = tweet_text[['text_stem']]

data.head()
# Out:
#                                            text_stem
# 0  pilpres ramadhanpun kemarin program 02 susun i...
# 1  goblok goblok presiden pecat panglima yusril i...
# 2             beda open house prabowo anies baswedan
# 3                        pdi p temu prabowo megawati
# 4  prabowo sambang rumah megawati ya gua ikhlas p...

# %%
# Install needed libraries
# !pip install tweet-preprocessor
# !pip install textblob
# !pip install wordcloud
# Out:
# Collecting tweet-preprocessor
#   Downloading tweet_preprocessor-0.6.0-py3-none-any.whl.metadata (5.9 kB)
# Downloading tweet_preprocessor-0.6.0-py3-none-any.whl (27 kB)
# Installing collected packages: tweet-preprocessor
# Successfully installed tweet-preprocessor-0.6.0
# Collecting textblob
#   Downloading textblob-0.18.0.post0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: nltk>=3.8 in c:\users\septi\anaconda3\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\septi\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\septi\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\septi\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\septi\anaconda3\lib\site-packages (from nltk>=3.8->textblob) (4.65.0)
# Requirement already satisfied: colorama in c:\users\septi\anaconda3\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.6)
# Downloading textblob-0.18.0.post0-py3-none-any.whl (626 kB)
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ----- ---------------------------------- 81.9/626.3 kB 2.3 MB/s eta 0:00:01
#    --------------- ------------------------ 245.8/626.3 kB 3.8 MB/s eta 0:00:01
#    -------------------- ------------------- 327.7/626.3 kB 2.5 MB/s eta 0:00:01
#    ------------------------------ --------- 471.0/626.3 kB 2.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 553.0/626.3 kB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 626.3/626.3 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.18.0.post0
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\septi\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\septi\anaconda3\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in c:\users\septi\anaconda3\lib\site-packages (from wordcloud) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\septi\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\septi\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\septi\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\septi\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\septi\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\septi\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\septi\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\septi\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl (300 kB)
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    ------- ------------------------------- 61.4/300.2 kB 656.4 kB/s eta 0:00:01
#    -------------------------------- ------- 245.8/300.2 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 300.2/300.2 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3

# %%
# import the libraries
import preprocessor as p
from textblob import TextBlob
from nltk.stem import PorterStemmer

# list data
lst_data = list(data['text_stem'])

# Start labelling
polarity = 0
status = []
total_positive = total_negative = total_netral = total = 0

for i, text in enumerate(lst_data):
    analysis = TextBlob(text)
    polarity += analysis.polarity

    if analysis.sentiment.polarity > 0.0:
        total_positive += 1
        status.append('Positive')
    elif analysis.sentiment.polarity == 0.0:
        total_netral += 1
        status.append('Netral')
    else:
        total_negative += 1
        status.append('Negative')

    total += 1

print('Sentiment labeling result:')
print('Total Positive:', total_positive)
print('Total Netral:', total_netral)
print('Total Negative:', total_negative)
print('Total data:', total)
# Out:
# Sentiment labeling result:
# Total Positive: 18
# Total Netral: 95
# Total Negative: 5
# Total data: 118

# %%
# adding the status
data['status'] = status
data.head()
# Out:
# C:\Users\septi\AppData\Local\Temp\ipykernel_10856\3899142590.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['status'] = status
#                                            text_stem  status
# 0  pilpres ramadhanpun kemarin program 02 susun i...  Netral
# 1  goblok goblok presiden pecat panglima yusril i...  Netral
# 2             beda open house prabowo anies baswedan  Netral
# 3                        pdi p temu prabowo megawati  Netral
# 4  prabowo sambang rumah megawati ya gua ikhlas p...  Netral

# %%
# import libraries for visualization
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

def plot_cloud(wordcloud):
    plt.figure(figsize=(10, 8))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

all_words = ' '.join(tweets for tweets in data['text_stem'])


wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    random_state = 42,
    
)
